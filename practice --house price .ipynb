# %% [markdown]
# ### Case Study 2:
# Load practice.csv file as a data-frame and perform following operations on the data-frame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('practice.csv')
df
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# 11          60       RL    11924      IR1    Inside       Gtl            9
# 12          20       RL    12968      IR2    Inside       Gtl            5
# 13          20       RL    10652      IR1    Inside       Gtl            7
# 14          20       RL    10920      IR1    Corner       Gtl            6
# 15          45       RM     6120      Reg    Corner       Gtl            7
# 16          20       RL    11241      IR1   CulDSac       Gtl            6
# 17          90       RL    10791      Reg    Inside       Gtl            4
# 18          20       RL    13695      Reg    Inside       Gtl            5
# 19          20       RL     7560      Reg    Inside       Gtl            5
# 20          60       RL    14215      IR1    Corner       Gtl            8
# 21          45       RM     7449      Reg    Inside       Gtl            7
# 22          20       RL     9742      Reg    Inside       Gtl            8
# 23         120       RM     4224      Reg    Inside       Gtl            5
# 24          20       RL     8246      IR1    Inside       Gtl            5
# 25          20       RL    14230      Reg    Corner       Gtl            8
# 26          20       RL     7200      Reg    Corner       Gtl            5
# 27          20       RL    11478      Reg    Inside       Gtl            8
# 28          20       RL    16321      IR1   CulDSac       Gtl            5
# 29          30       RM     6324      IR1    Inside       Gtl            4
#
#     YearBuilt  MasVnrArea ExterQual BsmtExposure
# 0        2003         196        Gd           No
# 1        1976           0        TA           Gd
# 2        2001         162        Gd           Mn
# 3        1915           0        TA           No
# 4        2000         350        Gd           Av
# 5        1993           0        TA           No
# 6        2004         186        Gd           Av
# 7        1973         240        TA           Mn
# 8        1931           0        TA           No
# 9        1939           0        TA           No
# 10       1965           0        TA           No
# 11       2005         286        Ex           No
# 12       1962           0        TA           No
# 13       2006         306        Gd           Av
# 14       1960         212        TA           No
# 15       1929           0        TA           No
# 16       1970         180        TA           No
# 17       1967           0        TA          NaN
# 18       2004           0        TA           No
# 19       1958           0        TA           No
# 20       2005         380        Gd           Av
# 21       1930           0        TA           No
# 22       2002         281        Gd           No
# 23       1976           0        TA           No
# 24       1968           0        TA           Mn
# 25       2007         640        Gd           No
# 26       1951           0        TA           Mn
# 27       2007         200        Gd           No
# 28       1957           0        TA           Gd
# 29       1927           0        TA           No

# %% [markdown]
# 1.	Display all columns

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotArea', 'LotShape', 'LotConfig',
#        'LandSlope', 'OverallQual', 'YearBuilt', 'MasVnrArea', 'ExterQual',
#        'BsmtExposure'],
#       dtype='object')

# %% [markdown]
# 2.	create numerical and categorical columns list

# %%
df.select_dtypes(include='number').head()
# Out:
#    MSSubClass  LotArea  OverallQual  YearBuilt  MasVnrArea
# 0          60     8450            7       2003         196
# 1          20     9600            6       1976           0
# 2          60    11250            7       2001         162
# 3          70     9550            7       1915           0
# 4          60    14260            8       2000         350

# %%
df.select_dtypes(include='object').head()
# Out:
#   MSZoning LotShape LotConfig LandSlope ExterQual BsmtExposure
# 0       RL      Reg    Inside       Gtl        Gd           No
# 1       RL      Reg       FR2       Gtl        TA           Gd
# 2       RL      IR1    Inside       Gtl        Gd           Mn
# 3       RL      IR1    Corner       Gtl        TA           No
# 4       RL      IR1       FR2       Gtl        Gd           Av

# %% [markdown]
# 3.	display size of the data-frame

# %%
df.shape
# Out:
# (30, 11)

# %% [markdown]
# 4.	rename column MSSubClass -> SubClass, MSZoning -> Zones

# %%
df.rename(columns={'MSSubClass':'SubClass','MSZoning':'Zones'})
# Out:
#     SubClass Zones  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0         60    RL     8450      Reg    Inside       Gtl            7
# 1         20    RL     9600      Reg       FR2       Gtl            6
# 2         60    RL    11250      IR1    Inside       Gtl            7
# 3         70    RL     9550      IR1    Corner       Gtl            7
# 4         60    RL    14260      IR1       FR2       Gtl            8
# 5         50    RL    14115      IR1    Inside       Gtl            5
# 6         20    RL    10084      Reg    Inside       Gtl            8
# 7         60    RL    10382      IR1    Corner       Gtl            7
# 8         50    RM     6120      Reg    Inside       Gtl            7
# 9        190    RL     7420      Reg    Corner       Gtl            5
# 10        20    RL    11200      Reg    Inside       Gtl            5
# 11        60    RL    11924      IR1    Inside       Gtl            9
# 12        20    RL    12968      IR2    Inside       Gtl            5
# 13        20    RL    10652      IR1    Inside       Gtl            7
# 14        20    RL    10920      IR1    Corner       Gtl            6
# 15        45    RM     6120      Reg    Corner       Gtl            7
# 16        20    RL    11241      IR1   CulDSac       Gtl            6
# 17        90    RL    10791      Reg    Inside       Gtl            4
# 18        20    RL    13695      Reg    Inside       Gtl            5
# 19        20    RL     7560      Reg    Inside       Gtl            5
# 20        60    RL    14215      IR1    Corner       Gtl            8
# 21        45    RM     7449      Reg    Inside       Gtl            7
# 22        20    RL     9742      Reg    Inside       Gtl            8
# 23       120    RM     4224      Reg    Inside       Gtl            5
# 24        20    RL     8246      IR1    Inside       Gtl            5
# 25        20    RL    14230      Reg    Corner       Gtl            8
# 26        20    RL     7200      Reg    Corner       Gtl            5
# 27        20    RL    11478      Reg    Inside       Gtl            8
# 28        20    RL    16321      IR1   CulDSac       Gtl            5
# 29        30    RM     6324      IR1    Inside       Gtl            4
#
#     YearBuilt  MasVnrArea ExterQual BsmtExposure col_value
# 0        2003         196        Gd           No        RL
# 1        1976           0        TA           Gd        RL
# 2        2001         162        Gd           Mn        RL
# 3        1915           0        TA           No        RL
# 4        2000         350        Gd           Av        RL
# 5        1993           0        TA           No        RL
# 6        2004         186        Gd           Av        RL
# 7        1973         240        TA           Mn        RL
# 8        1931           0        TA           No        RM
# 9        1939           0        TA           No        RL
# 10       1965           0        TA           No        RL
# 11       2005         286        Ex           No        RL
# 12       1962           0        TA           No        RL
# 13       2006         306        Gd           Av        RL
# 14       1960         212        TA           No        RL
# 15       1929           0        TA           No        RM
# 16       1970         180        TA           No        RL
# 17       1967           0        TA         None        RL
# 18       2004           0        TA           No        RL
# 19       1958           0        TA           No        RL
# 20       2005         380        Gd           Av        RL
# 21       1930           0        TA           No        RM
# 22       2002         281        Gd           No        RL
# 23       1976           0        TA           No        RM
# 24       1968           0        TA           Mn        RL
# 25       2007         640        Gd           No        RL
# 26       1951           0        TA           Mn        RL
# 27       2007         200        Gd           No        RL
# 28       1957           0        TA           Gd        RL
# 29       1927           0        TA           No        RM

# %% [markdown]
# 5.	display distinct values for Zoning, LotShape, LotConfig

# %%
column_values = df[["MSZoning","LotShape","LotConfig"]].values. ravel()
unv = pd.unique(column_values)
print(unv)
# Out:
# ['RL' 'Reg' 'Inside' 'FR2' 'IR1' 'Corner' 'RM' 'IR2' 'CulDSac']

# %% [markdown]
# 6.	display count of distinct values for Zoning, LotShape, LotConfig

# %%
df[["MSZoning","LotShape","LotConfig"]].nunique()
# Out:
# MSZoning     2
# LotShape     3
# LotConfig    4
# dtype: int64

# %% [markdown]
# 7.	max, min of column YearBuilt

# %%
df.YearBuilt.max()
# Out:
# 2007

# %%
df.YearBuilt.min()
# Out:
# 1915

# %% [markdown]
# 8.	create a new column “year_diff’. This will be holding difference of current year and YearBuilt

# %%
from datetime import datetime
df['year_diff']= datetime.today().year - df.YearBuilt
df
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# 11          60       RL    11924      IR1    Inside       Gtl            9
# 12          20       RL    12968      IR2    Inside       Gtl            5
# 13          20       RL    10652      IR1    Inside       Gtl            7
# 14          20       RL    10920      IR1    Corner       Gtl            6
# 15          45       RM     6120      Reg    Corner       Gtl            7
# 16          20       RL    11241      IR1   CulDSac       Gtl            6
# 17          90       RL    10791      Reg    Inside       Gtl            4
# 18          20       RL    13695      Reg    Inside       Gtl            5
# 19          20       RL     7560      Reg    Inside       Gtl            5
# 20          60       RL    14215      IR1    Corner       Gtl            8
# 21          45       RM     7449      Reg    Inside       Gtl            7
# 22          20       RL     9742      Reg    Inside       Gtl            8
# 23         120       RM     4224      Reg    Inside       Gtl            5
# 24          20       RL     8246      IR1    Inside       Gtl            5
# 25          20       RL    14230      Reg    Corner       Gtl            8
# 26          20       RL     7200      Reg    Corner       Gtl            5
# 27          20       RL    11478      Reg    Inside       Gtl            8
# 28          20       RL    16321      IR1   CulDSac       Gtl            5
# 29          30       RM     6324      IR1    Inside       Gtl            4
#
#     YearBuilt  MasVnrArea ExterQual BsmtExposure col_value  year_diff
# 0        2003         196        Gd           No        RL         18
# 1        1976           0        TA           Gd        RL         45
# 2        2001         162        Gd           Mn        RL         20
# 3        1915           0        TA           No        RL        106
# 4        2000         350        Gd           Av        RL         21
# 5        1993           0        TA           No        RL         28
# 6        2004         186        Gd           Av        RL         17
# 7        1973         240        TA           Mn        RL         48
# 8        1931           0        TA           No        RM         90
# 9        1939           0        TA           No        RL         82
# 10       1965           0        TA           No        RL         56
# 11       2005         286        Ex           No        RL         16
# 12       1962           0        TA           No        RL         59
# 13       2006         306        Gd           Av        RL         15
# 14       1960         212        TA           No        RL         61
# 15       1929           0        TA           No        RM         92
# 16       1970         180        TA           No        RL         51
# 17       1967           0        TA         None        RL         54
# 18       2004           0        TA           No        RL         17
# 19       1958           0        TA           No        RL         63
# 20       2005         380        Gd           Av        RL         16
# 21       1930           0        TA           No        RM         91
# 22       2002         281        Gd           No        RL         19
# 23       1976           0        TA           No        RM         45
# 24       1968           0        TA           Mn        RL         53
# 25       2007         640        Gd           No        RL         14
# 26       1951           0        TA           Mn        RL         70
# 27       2007         200        Gd           No        RL         14
# 28       1957           0        TA           Gd        RL         64
# 29       1927           0        TA           No        RM         94

# %% [markdown]
# 9.	display distinct MSZoning for each OverallQual

# %%
df.groupby('OverallQual')['MSZoning'].unique()
# Out:
# OverallQual
# 4    [RL, RM]
# 5    [RL, RM]
# 6        [RL]
# 7    [RL, RM]
# 8        [RL]
# 9        [RL]
# Name: MSZoning, dtype: object

# %% [markdown]
# 10.	What is the maximum LotArea where  BsmtExposure = Mn?

# %%
##df.groupby('BsmtExposure')['LotArea'].max()
df[df.BsmtExposure == 'Mn']['LotArea'].max()
# Out:
# 16321

# %% [markdown]
# 11.	Sort dataframe based on following columns and orders: MSSubClass; ascending, YearBuilt; descending

# %%
df.sort_values(by=['MSSubClass'],ascending=True , inplace=False)
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 14          20       RL    10920      IR1    Corner       Gtl            6
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 27          20       RL    11478      Reg    Inside       Gtl            8
# 26          20       RL     7200      Reg    Corner       Gtl            5
# 25          20       RL    14230      Reg    Corner       Gtl            8
# 24          20       RL     8246      IR1    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 22          20       RL     9742      Reg    Inside       Gtl            8
# 19          20       RL     7560      Reg    Inside       Gtl            5
# 18          20       RL    13695      Reg    Inside       Gtl            5
# 10          20       RL    11200      Reg    Inside       Gtl            5
# 16          20       RL    11241      IR1   CulDSac       Gtl            6
# 12          20       RL    12968      IR2    Inside       Gtl            5
# 13          20       RL    10652      IR1    Inside       Gtl            7
# 28          20       RL    16321      IR1   CulDSac       Gtl            5
# 29          30       RM     6324      IR1    Inside       Gtl            4
# 21          45       RM     7449      Reg    Inside       Gtl            7
# 15          45       RM     6120      Reg    Corner       Gtl            7
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 11          60       RL    11924      IR1    Inside       Gtl            9
# 20          60       RL    14215      IR1    Corner       Gtl            8
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 3           70       RL     9550      IR1    Corner       Gtl            7
# 17          90       RL    10791      Reg    Inside       Gtl            4
# 23         120       RM     4224      Reg    Inside       Gtl            5
# 9          190       RL     7420      Reg    Corner       Gtl            5
#
#     YearBuilt  MasVnrArea ExterQual BsmtExposure col_value  year_diff
# 14       1960         212        TA           Mn        RL         61
# 1        1976           0        TA           Mn        RL         45
# 27       2007         200        Gd           Mn        RL         14
# 26       1951           0        TA           Mn        RL         70
# 25       2007         640        Gd           Mn        RL         14
# 24       1968           0        TA           Mn        RL         53
# 6        2004         186        Gd           Mn        RL         17
# 22       2002         281        Gd           Mn        RL         19
# 19       1958           0        TA           Mn        RL         63
# 18       2004           0        TA           Mn        RL         17
# 10       1965           0        TA           Mn        RL         56
# 16       1970         180        TA           Mn        RL         51
# 12       1962           0        TA           Mn        RL         59
# 13       2006         306        Gd           Mn        RL         15
# 28       1957           0        TA           Mn        RL         64
# 29       1927           0        TA           Mn        RM         94
# 21       1930           0        TA           Mn        RM         91
# 15       1929           0        TA           Mn        RM         92
# 8        1931           0        TA           Mn        RM         90
# 5        1993           0        TA           Mn        RL         28
# 11       2005         286        Ex           Mn        RL         16
# 20       2005         380        Gd           Mn        RL         16
# 7        1973         240        TA           Mn        RL         48
# 4        2000         350        Gd           Mn        RL         21
# 2        2001         162        Gd           Mn        RL         20
# 0        2003         196        Gd           Mn        RL         18
# 3        1915           0        TA           Mn        RL        106
# 17       1967           0        TA           Mn        RL         54
# 23       1976           0        TA           Mn        RM         45
# 9        1939           0        TA           Mn        RL         82

# %%
df.sort_values(by=['YearBuilt'],ascending=False , inplace=False)
# Out:
#     MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 25          20       RL    14230      Reg    Corner       Gtl            8
# 27          20       RL    11478      Reg    Inside       Gtl            8
# 13          20       RL    10652      IR1    Inside       Gtl            7
# 11          60       RL    11924      IR1    Inside       Gtl            9
# 20          60       RL    14215      IR1    Corner       Gtl            8
# 18          20       RL    13695      Reg    Inside       Gtl            5
# 6           20       RL    10084      Reg    Inside       Gtl            8
# 0           60       RL     8450      Reg    Inside       Gtl            7
# 22          20       RL     9742      Reg    Inside       Gtl            8
# 2           60       RL    11250      IR1    Inside       Gtl            7
# 4           60       RL    14260      IR1       FR2       Gtl            8
# 5           50       RL    14115      IR1    Inside       Gtl            5
# 23         120       RM     4224      Reg    Inside       Gtl            5
# 1           20       RL     9600      Reg       FR2       Gtl            6
# 7           60       RL    10382      IR1    Corner       Gtl            7
# 16          20       RL    11241      IR1   CulDSac       Gtl            6
# 24          20       RL     8246      IR1    Inside       Gtl            5
# 17          90       RL    10791      Reg    Inside       Gtl            4
# 10          20       RL    11200      Reg    Inside       Gtl            5
# 12          20       RL    12968      IR2    Inside       Gtl            5
# 14          20       RL    10920      IR1    Corner       Gtl            6
# 19          20       RL     7560      Reg    Inside       Gtl            5
# 28          20       RL    16321      IR1   CulDSac       Gtl            5
# 26          20       RL     7200      Reg    Corner       Gtl            5
# 9          190       RL     7420      Reg    Corner       Gtl            5
# 8           50       RM     6120      Reg    Inside       Gtl            7
# 21          45       RM     7449      Reg    Inside       Gtl            7
# 15          45       RM     6120      Reg    Corner       Gtl            7
# 29          30       RM     6324      IR1    Inside       Gtl            4
# 3           70       RL     9550      IR1    Corner       Gtl            7
#
#     YearBuilt  MasVnrArea ExterQual BsmtExposure col_value  year_diff
# 25       2007         640        Gd           Mn        RL         14
# 27       2007         200        Gd           Mn        RL         14
# 13       2006         306        Gd           Mn        RL         15
# 11       2005         286        Ex           Mn        RL         16
# 20       2005         380        Gd           Mn        RL         16
# 18       2004           0        TA           Mn        RL         17
# 6        2004         186        Gd           Mn        RL         17
# 0        2003         196        Gd           Mn        RL         18
# 22       2002         281        Gd           Mn        RL         19
# 2        2001         162        Gd           Mn        RL         20
# 4        2000         350        Gd           Mn        RL         21
# 5        1993           0        TA           Mn        RL         28
# 23       1976           0        TA           Mn        RM         45
# 1        1976           0        TA           Mn        RL         45
# 7        1973         240        TA           Mn        RL         48
# 16       1970         180        TA           Mn        RL         51
# 24       1968           0        TA           Mn        RL         53
# 17       1967           0        TA           Mn        RL         54
# 10       1965           0        TA           Mn        RL         56
# 12       1962           0        TA           Mn        RL         59
# 14       1960         212        TA           Mn        RL         61
# 19       1958           0        TA           Mn        RL         63
# 28       1957           0        TA           Mn        RL         64
# 26       1951           0        TA           Mn        RL         70
# 9        1939           0        TA           Mn        RL         82
# 8        1931           0        TA           Mn        RM         90
# 21       1930           0        TA           Mn        RM         91
# 15       1929           0        TA           Mn        RM         92
# 29       1927           0        TA           Mn        RM         94
# 3        1915           0        TA           Mn        RL        106

# %% [markdown]
# 12.	What is average OverallQual.

# %%
df. OverallQual.mean()
# Out:
# 6.3

# %% [markdown]
# 13.	convert column ‘YearBuilt’ into date type.

# %%
#df.select_dtypes(include='date')

df['YearBuilt'] = pd.to_datetime(df['YearBuilt'])
df.dtypes
# Out:
# MSSubClass               int64
# MSZoning                object
# LotArea                  int64
# LotShape                object
# LotConfig               object
# LandSlope               object
# OverallQual              int64
# YearBuilt       datetime64[ns]
# MasVnrArea               int64
# ExterQual               object
# BsmtExposure            object
# col_value               object
# year_diff                int64
# dtype: object

# %% [markdown]
# 14.	Group by YearBuilt and find maximum OverallQal

# %%
df.groupby('OverallQual')['YearBuilt'].max()
# Out:
# OverallQual
# 4   1970-01-01 00:00:00.000001967
# 5   1970-01-01 00:00:00.000002004
# 6   1970-01-01 00:00:00.000001976
# 7   1970-01-01 00:00:00.000002006
# 8   1970-01-01 00:00:00.000002007
# 9   1970-01-01 00:00:00.000002005
# Name: YearBuilt, dtype: datetime64[ns]

# %% [markdown]
# 15.	Load the practice.csv again with MSSubClass as new index

# %%
df1= pd.read_csv('practice.csv')
df1.set_index('MSSubClass')
# Out:
#            MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# MSSubClass
# 60               RL     8450      Reg    Inside       Gtl            7
# 20               RL     9600      Reg       FR2       Gtl            6
# 60               RL    11250      IR1    Inside       Gtl            7
# 70               RL     9550      IR1    Corner       Gtl            7
# 60               RL    14260      IR1       FR2       Gtl            8
# 50               RL    14115      IR1    Inside       Gtl            5
# 20               RL    10084      Reg    Inside       Gtl            8
# 60               RL    10382      IR1    Corner       Gtl            7
# 50               RM     6120      Reg    Inside       Gtl            7
# 190              RL     7420      Reg    Corner       Gtl            5
# 20               RL    11200      Reg    Inside       Gtl            5
# 60               RL    11924      IR1    Inside       Gtl            9
# 20               RL    12968      IR2    Inside       Gtl            5
# 20               RL    10652      IR1    Inside       Gtl            7
# 20               RL    10920      IR1    Corner       Gtl            6
# 45               RM     6120      Reg    Corner       Gtl            7
# 20               RL    11241      IR1   CulDSac       Gtl            6
# 90               RL    10791      Reg    Inside       Gtl            4
# 20               RL    13695      Reg    Inside       Gtl            5
# 20               RL     7560      Reg    Inside       Gtl            5
# 60               RL    14215      IR1    Corner       Gtl            8
# 45               RM     7449      Reg    Inside       Gtl            7
# 20               RL     9742      Reg    Inside       Gtl            8
# 120              RM     4224      Reg    Inside       Gtl            5
# 20               RL     8246      IR1    Inside       Gtl            5
# 20               RL    14230      Reg    Corner       Gtl            8
# 20               RL     7200      Reg    Corner       Gtl            5
# 20               RL    11478      Reg    Inside       Gtl            8
# 20               RL    16321      IR1   CulDSac       Gtl            5
# 30               RM     6324      IR1    Inside       Gtl            4
#
#             YearBuilt  MasVnrArea ExterQual BsmtExposure
# MSSubClass
# 60               2003         196        Gd           No
# 20               1976           0        TA           Gd
# 60               2001         162        Gd           Mn
# 70               1915           0        TA           No
# 60               2000         350        Gd           Av
# 50               1993           0        TA           No
# 20               2004         186        Gd           Av
# 60               1973         240        TA           Mn
# 50               1931           0        TA           No
# 190              1939           0        TA           No
# 20               1965           0        TA           No
# 60               2005         286        Ex           No
# 20               1962           0        TA           No
# 20               2006         306        Gd           Av
# 20               1960         212        TA           No
# 45               1929           0        TA           No
# 20               1970         180        TA           No
# 90               1967           0        TA          NaN
# 20               2004           0        TA           No
# 20               1958           0        TA           No
# 60               2005         380        Gd           Av
# 45               1930           0        TA           No
# 20               2002         281        Gd           No
# 120              1976           0        TA           No
# 20               1968           0        TA           Mn
# 20               2007         640        Gd           No
# 20               1951           0        TA           Mn
# 20               2007         200        Gd           No
# 20               1957           0        TA           Gd
# 30               1927           0        TA           No

# %% [markdown]
# 16.	Convert LotArea as numpy array

# %%
df.LotArea.to_numpy()
# Out:
# array([ 8450,  9600, 11250,  9550, 14260, 14115, 10084, 10382,  6120,
#         7420, 11200, 11924, 12968, 10652, 10920,  6120, 11241, 10791,
#        13695,  7560, 14215,  7449,  9742,  4224,  8246, 14230,  7200,
#        11478, 16321,  6324], dtype=int64)

# %% [markdown]
# 17.	In column MasVnrArea replace 0 with -1

# %%
df['MasVnrArea']= df.replace('0','-1')


df["MasVnrArea"].replace({"0":"-1"} ,inplace=True)
df
# Out:
#    MSSubClass MSZoning  LotArea LotShape LotConfig LandSlope  OverallQual  \
# 0          60       RL     8450      Reg    Inside       Gtl            7
# 1          20       RL     9600      Reg       FR2       Gtl            6
# 2          60       RL    11250      IR1    Inside       Gtl            7
# 3          70       RL     9550      IR1    Corner       Gtl            7
# 4          60       RL    14260      IR1       FR2       Gtl            8
# 5          50       RL    14115      IR1    Inside       Gtl            5
# 6          20       RL    10084      Reg    Inside       Gtl            8
# 7          60       RL    10382      IR1    Corner       Gtl            7
# 8          50       RM     6120      Reg    Inside       Gtl            7
# 9         190       RL     7420      Reg    Corner       Gtl            5
# 10         20       RL    11200      Reg    Inside       Gtl            5
# 11         60       RL    11924      IR1    Inside       Gtl            9
# 12         20       RL    12968      IR2    Inside       Gtl            5
# 13         20       RL    10652      IR1    Inside       Gtl            7
# 14         20       RL    10920      IR1    Corner       Gtl            6
# 15         45       RM     6120      Reg    Corner       Gtl            7
# 16         20       RL    11241      IR1   CulDSac       Gtl            6
# 17         90       RL    10791      Reg    Inside       Gtl            4
# 18         20       RL    13695      Reg    Inside       Gtl            5
# 19         20       RL     7560      Reg    Inside       Gtl            5
# 20         60       RL    14215      IR1    Corner       Gtl            8
# 21         45       RM     7449      Reg    Inside       Gtl            7
# 22         20       RL     9742      Reg    Inside       Gtl            8
# 23        120       RM     4224      Reg    Inside       Gtl            5
# 24         20       RL     8246      IR1    Inside       Gtl            5
# 25         20       RL    14230      Reg    Corner       Gtl            8
# 26         20       RL     7200      Reg    Corner       Gtl            5
# 27         20       RL    11478      Reg    Inside       Gtl            8
# 28         20       RL    16321      IR1   CulDSac       Gtl            5
# 29         30       RM     6324      IR1    Inside       Gtl            4
#
#                        YearBuilt  MasVnrArea ExterQual BsmtExposure col_value  \
# 0  1970-01-01 00:00:00.000002003          60        Gd           Mn        RL
# 1  1970-01-01 00:00:00.000001976          20        TA           Mn        RL
# 2  1970-01-01 00:00:00.000002001          60        Gd           Mn        RL
# 3  1970-01-01 00:00:00.000001915          70        TA           Mn        RL
# 4  1970-01-01 00:00:00.000002000          60        Gd           Mn        RL
# 5  1970-01-01 00:00:00.000001993          50        TA           Mn        RL
# 6  1970-01-01 00:00:00.000002004          20        Gd           Mn        RL
# 7  1970-01-01 00:00:00.000001973          60        TA           Mn        RL
# 8  1970-01-01 00:00:00.000001931          50        TA           Mn        RM
# 9  1970-01-01 00:00:00.000001939         190        TA           Mn        RL
# 10 1970-01-01 00:00:00.000001965          20        TA           Mn        RL
# 11 1970-01-01 00:00:00.000002005          60        Ex           Mn        RL
# 12 1970-01-01 00:00:00.000001962          20        TA           Mn        RL
# 13 1970-01-01 00:00:00.000002006          20        Gd           Mn        RL
# 14 1970-01-01 00:00:00.000001960          20        TA           Mn        RL
# 15 1970-01-01 00:00:00.000001929          45        TA           Mn        RM
# 16 1970-01-01 00:00:00.000001970          20        TA           Mn        RL
# 17 1970-01-01 00:00:00.000001967          90        TA           Mn        RL
# 18 1970-01-01 00:00:00.000002004          20        TA           Mn        RL
# 19 1970-01-01 00:00:00.000001958          20        TA           Mn        RL
# 20 1970-01-01 00:00:00.000002005          60        Gd           Mn        RL
# 21 1970-01-01 00:00:00.000001930          45        TA           Mn        RM
# 22 1970-01-01 00:00:00.000002002          20        Gd           Mn        RL
# 23 1970-01-01 00:00:00.000001976         120        TA           Mn        RM
# 24 1970-01-01 00:00:00.000001968          20        TA           Mn        RL
# 25 1970-01-01 00:00:00.000002007          20        Gd           Mn        RL
# 26 1970-01-01 00:00:00.000001951          20        TA           Mn        RL
# 27 1970-01-01 00:00:00.000002007          20        Gd           Mn        RL
# 28 1970-01-01 00:00:00.000001957          20        TA           Mn        RL
# 29 1970-01-01 00:00:00.000001927          30        TA           Mn        RM
#
#     year_diff
# 0          18
# 1          45
# 2          20
# 3         106
# 4          21
# 5          28
# 6          17
# 7          48
# 8          90
# 9          82
# 10         56
# 11         16
# 12         59
# 13         15
# 14         61
# 15         92
# 16         51
# 17         54
# 18         17
# 19         63
# 20         16
# 21         91
# 22         19
# 23         45
# 24         53
# 25         14
# 26         70
# 27         14
# 28         64
# 29         94

# %% [markdown]
# 18.	Check if there is/are any Null values (NaN) in the data given

# %%
count = df.isnull().sum()
per = df.isnull().sum()
pd.concat([pd.DataFrame(count, columns=['count'])], axis = 1)
# Out:
#               count
# MSSubClass        0
# MSZoning          0
# LotArea           0
# LotShape          0
# LotConfig         0
# LandSlope         0
# OverallQual       0
# YearBuilt         0
# MasVnrArea        0
# ExterQual         0
# BsmtExposure      0
# col_value         0
# year_diff         0

# %% [markdown]
# 19.	Display percentage of missing values in each column if any

# %%
count = df.isnull().sum()
per = df.isnull().sum()/df.shape[0]*100
pd.concat([pd.DataFrame(count, columns=['count']),pd.DataFrame(per, columns=['percentage']) ], axis = 1).sort_values('percentage')
# Out:
#               count  percentage
# MSSubClass        0         0.0
# MSZoning          0         0.0
# LotArea           0         0.0
# LotShape          0         0.0
# LotConfig         0         0.0
# LandSlope         0         0.0
# OverallQual       0         0.0
# YearBuilt         0         0.0
# MasVnrArea        0         0.0
# ExterQual         0         0.0
# BsmtExposure      0         0.0
# col_value         0         0.0
# year_diff         0         0.0

# %% [markdown]
# 20.	Select records where LotConfig is Inside

# %%
df[['LotConfig']]=='Inside'
# Out:
#     LotConfig
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
# 5        True
# 6        True
# 7       False
# 8        True
# 9       False
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16      False
# 17       True
# 18       True
# 19       True
# 20      False
# 21       True
# 22       True
# 23       True
# 24       True
# 25      False
# 26      False
# 27       True
# 28      False
# 29       True

# %% [markdown]
# 21.	Make a new dataframe with only numeric columns

# %%
df.select_dtypes(include='number')
# Out:
#     LotArea  OverallQual  MasVnrArea  year_diff
# 0      8450            7          60         18
# 1      9600            6          20         45
# 2     11250            7          60         20
# 3      9550            7          70        106
# 4     14260            8          60         21
# 5     14115            5          50         28
# 6     10084            8          20         17
# 7     10382            7          60         48
# 8      6120            7          50         90
# 9      7420            5         190         82
# 10    11200            5          20         56
# 11    11924            9          60         16
# 12    12968            5          20         59
# 13    10652            7          20         15
# 14    10920            6          20         61
# 15     6120            7          45         92
# 16    11241            6          20         51
# 17    10791            4          90         54
# 18    13695            5          20         17
# 19     7560            5          20         63
# 20    14215            8          60         16
# 21     7449            7          45         91
# 22     9742            8          20         19
# 23     4224            5         120         45
# 24     8246            5          20         53
# 25    14230            8          20         14
# 26     7200            5          20         70
# 27    11478            8          20         14
# 28    16321            5          20         64
# 29     6324            4          30         94

# %% [markdown]
# 22.	Make a new dataframe with only factorial/string columns

# %%
df.select_dtypes(include='object')
# Out:
#    MSSubClass MSZoning LotShape LotConfig LandSlope ExterQual BsmtExposure  \
# 0          60       RL      Reg    Inside       Gtl        Gd           Mn
# 1          20       RL      Reg       FR2       Gtl        TA           Mn
# 2          60       RL      IR1    Inside       Gtl        Gd           Mn
# 3          70       RL      IR1    Corner       Gtl        TA           Mn
# 4          60       RL      IR1       FR2       Gtl        Gd           Mn
# 5          50       RL      IR1    Inside       Gtl        TA           Mn
# 6          20       RL      Reg    Inside       Gtl        Gd           Mn
# 7          60       RL      IR1    Corner       Gtl        TA           Mn
# 8          50       RM      Reg    Inside       Gtl        TA           Mn
# 9         190       RL      Reg    Corner       Gtl        TA           Mn
# 10         20       RL      Reg    Inside       Gtl        TA           Mn
# 11         60       RL      IR1    Inside       Gtl        Ex           Mn
# 12         20       RL      IR2    Inside       Gtl        TA           Mn
# 13         20       RL      IR1    Inside       Gtl        Gd           Mn
# 14         20       RL      IR1    Corner       Gtl        TA           Mn
# 15         45       RM      Reg    Corner       Gtl        TA           Mn
# 16         20       RL      IR1   CulDSac       Gtl        TA           Mn
# 17         90       RL      Reg    Inside       Gtl        TA           Mn
# 18         20       RL      Reg    Inside       Gtl        TA           Mn
# 19         20       RL      Reg    Inside       Gtl        TA           Mn
# 20         60       RL      IR1    Corner       Gtl        Gd           Mn
# 21         45       RM      Reg    Inside       Gtl        TA           Mn
# 22         20       RL      Reg    Inside       Gtl        Gd           Mn
# 23        120       RM      Reg    Inside       Gtl        TA           Mn
# 24         20       RL      IR1    Inside       Gtl        TA           Mn
# 25         20       RL      Reg    Corner       Gtl        Gd           Mn
# 26         20       RL      Reg    Corner       Gtl        TA           Mn
# 27         20       RL      Reg    Inside       Gtl        Gd           Mn
# 28         20       RL      IR1   CulDSac       Gtl        TA           Mn
# 29         30       RM      IR1    Inside       Gtl        TA           Mn
#
#    col_value
# 0         RL
# 1         RL
# 2         RL
# 3         RL
# 4         RL
# 5         RL
# 6         RL
# 7         RL
# 8         RM
# 9         RL
# 10        RL
# 11        RL
# 12        RL
# 13        RL
# 14        RL
# 15        RM
# 16        RL
# 17        RL
# 18        RL
# 19        RL
# 20        RL
# 21        RM
# 22        RL
# 23        RM
# 24        RL
# 25        RL
# 26        RL
# 27        RL
# 28        RL
# 29        RM

# %% [markdown]
# 23.	Drop column ExterQual

# %%
df.drop('ExterQual', axis=1, inplace=True)--- deketed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-188-69375cc2ad58> in <module>
# ----> 1 df.drop('ExterQual', axis=1, inplace=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['ExterQual'] not found in axis"

# %% [markdown]
# 24.	Group data on LotShape and find average LotArea

# %%
df.groupby('LotShape')['LotArea'].mean()
# Out:
# LotShape
# IR1    11492.307692
# IR2    12968.000000
# Reg     9085.187500
# Name: LotArea, dtype: float64

# %% [markdown]
# 25.	Write code to get a pivot table as shown (average of MSSubClass)
